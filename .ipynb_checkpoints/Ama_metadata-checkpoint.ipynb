# %%
import numpy as np
import pandas as pd

# %%
#meta_dat = [i.strip().split("::") for i in open('../metadata.json', 'r',encoding = "ISO-8859-1").readlines()]

# %%
# Reading files stored in EC2 memory
#books_ratings = pd.read_csv('../ratings_Books.csv', header=None)

# %%
#books_ratings.columns = ['UserID','ItemID','rating','Timestamp']

# %%
#books_ratings.head(5)

# %%
pip install --upgrade pip
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install --upgrade pip
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
# Reading json data files from S3 using lazyread
# import boto3
# from lazyreader import lazyread
# client = boto3.client('s3')
# s3_object = client.get_object(Bucket='santhoshi-sparkle', Key='amazon-data/s3-test.json')
# body = s3_object['Body']

# for doc in lazyread(body, delimiter=b'\n'):
#     print(doc)

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install lazyreader
# Out:
# Requirement already up-to-date: pip in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (18.0)
# Requirement already satisfied: lazyreader in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (1.0.1)

# %%
import boto3
import lazyreader
from lazyreader import lazyread
client = boto3.client('s3')
s3_object = client.get_object(Bucket='santhoshi-sparkle', Key='amazon-data/meta_Books.json')
body = s3_object['Body']
count = 1

for doc in lazyread(body, delimiter=b'\n'):
    print(doc)
    count = count +1
    if count > 4:
        break
# Out:
# b"{'asin': '0001048791', 'salesRank': {'Books': 6334800}, 'imUrl': 'http://ecx.images-amazon.com/images/I/51MKP0T4DBL.jpg', 'categories': [['Books']], 'title': 'The Crucible: Performed by Stuart Pankin, Jerome Dempsey &amp; Cast'}\n"
# b"{'asin': '0001048775', 'description': 'William Shakespeare is widely regarded as the greatest playwright the world has seen. He produced an astonishing amount of work; 37 plays, 154 sonnets, and 5 poems. He died on 23rd April 1616, aged 52, and was buried in the Holy Trinity Church, Stratford.', 'title': 'Measure for Measure: Complete &amp; Unabridged', 'imUrl': 'http://ecx.images-amazon.com/images/I/5166EBHDQYL.jpg', 'salesRank': {'Books': 13243226}, 'categories': [['Books']]}\n"
# b'{\'asin\': \'0001048236\', \'categories\': [[\'Books\']], \'description\': "&#34;One thing is certain, Sherlockians, put aside your Baring-GouldAnnotated, your Folio SocietyIllustrated-for the time being, the Oxford is the edition to curl up with on a winter\'s night&#34;--The Chicago Tribune&#34;An incomparable gift book; or, should you find it impossible to surrender up such treasures, the best of gifts to oneself&#34;--USA Today&#34;To the true Sherlockian, this will be a treasure; to otherwise diverted detective story fans, it is a rich lode for discovery&#34;--Denver Post&#34;The complete and authentic adventures of the legendary detective--expertly edited and annotated by a team of Holmes scholars....in a handsome, boxed set....A lovely gift&#34;--The Christian Science Monitor&#34;Here in nine volumes...are all the adventures of Holmes and Watson. Each book has an introduction, something new and fascinating for even the most devoted Holmesians plus a series of intelligent notes at the back of each volume.&#34;--Oxford Times&#34;TheOxford Sherlock Holmes, a new edition of the stories, is a splendid piece of publishing. Nine compact volumes, beautifully produced, each with a stimulating introduction; clear type, accurate texts, a handy chronology, a helpful bibliography. And, most valuable of all, explanatory notes running to 50 pages or more per volume.&#34; --John Gross, writing inSunday Telegraph--This text refers to thePaperbackedition.", \'title\': \'The Sherlock Holmes Audio Collection\', \'price\': 9.26, \'salesRank\': {\'Books\': 8973864}, \'imUrl\': \'http://ecx.images-amazon.com/images/I/51DH145C5JL.jpg\', \'related\': {\'also_viewed\': [\'1442300191\', \'9626349786\', \'1602837155\', \'1598879162\', \'1400115159\', \'1478396202\', \'1408426250\', \'B007PM2A4A\', \'1609980603\'], \'buy_after_viewing\': [\'0312089457\']}}\n'
# b'{\'asin\': \'0000401048\', \'title\': "The rogue of publishers\' row;: Confessions of a publisher (A Banner Book)", \'imUrl\': \'http://ecx.images-amazon.com/images/I/41bchvIfgaL.jpg\', \'related\': {\'also_viewed\': [\'068240103X\']}, \'salesRank\': {\'Books\': 6448843}, \'categories\': [[\'Books\']]}\n'

# %%
# !{sys.executable} -m pip install smart_open
# Out:
# Requirement already satisfied: smart_open in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied: boto3 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from smart_open) (1.7.60)
# Requirement already satisfied: boto>=2.32 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from smart_open) (2.49.0)
# Requirement already satisfied: bz2file in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from smart_open) (0.98)
# Requirement already satisfied: requests in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from smart_open) (2.19.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart_open) (0.9.3)
# Requirement already satisfied: botocore<1.11.0,>=1.10.60 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart_open) (1.10.60)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart_open) (0.1.13)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart_open) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart_open) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart_open) (2018.4.16)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart_open) (1.23)
# Requirement already satisfied: docutils>=0.10 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.11.0,>=1.10.60->boto3->smart_open) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.11.0,>=1.10.60->boto3->smart_open) (2.7.3)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.11.0,>=1.10.60->boto3->smart_open) (1.11.0)

# %%
from smart_open import smart_open

# %%
# Reding csv file from S3 and converting it into dataframe
initial_df = pd.read_csv(smart_open('s3://santhoshi-sparkle/amazon-data/ratings_Books.csv'), header = None)

# %%
initial_df.columns = ['UserID','ItemID','rating','Timestamp']

# %%
#initial_df['Timestamp'] = pd.to_datetime(initial_df.Timestamp,unit='s')

# %%
#initial_df['new'] = initial_df['Timestamp'].dt.date
initial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22507155 entries, 0 to 22507154
# Data columns (total 4 columns):
# UserID       object
# ItemID       object
# rating       float64
# Timestamp    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 686.9+ MB

# %%
initial_df.head(5)
new_df = initial_df.drop('Timestamp', axis = 1)

# %%
missings = new_df.isnull().sum()

# %%
initial_df.shape
missings
# Out:
# UserID    0
# ItemID    0
# rating    0
# dtype: int64

# %%
import json
import ast 
records = []
count = 1
for line in smart_open('s3://santhoshi-sparkle/amazon-data/meta_Books.json'):
    mydict = ast.literal_eval(line.decode("utf-8"))
    count = count + 1
    records.append(mydict)
    if count > 15:
        break

# %%
records
# Out:
# [{'asin': '0001048791',
#   'salesRank': {'Books': 6334800},
#   'imUrl': 'http://ecx.images-amazon.com/images/I/51MKP0T4DBL.jpg',
#   'categories': [['Books']],
#   'title': 'The Crucible: Performed by Stuart Pankin, Jerome Dempsey &amp; Cast'},
#  {'asin': '0001048775',
#   'description': 'William Shakespeare is widely regarded as the greatest playwright the world has seen. He produced an astonishing amount of work; 37 plays, 154 sonnets, and 5 poems. He died on 23rd April 1616, aged 52, and was buried in the Holy Trinity Church, Stratford.',
#   'title': 'Measure for Measure: Complete &amp; Unabridged',
#   'imUrl': 'http://ecx.images-amazon.com/images/I/5166EBHDQYL.jpg',
#   'salesRank': {'Books': 13243226},
#   'categories': [['Books']]},
#  {'asin': '0001048236',
#   'categories': [['Books']],
#   'description': "&#34;One thing is certain, Sherlockians, put aside your Baring-GouldAnnotated, your Folio SocietyIllustrated-for the time being, the Oxford is the edition to curl up with on a winter's night&#34;--The Chicago Tribune&#34;An incomparable gift book; or, should you find it impossible to surrender up such treasures, the best of gifts to oneself&#34;--USA Today&#34;To the true Sherlockian, this will be a treasure; to otherwise diverted detective story fans, it is a rich lode for discovery&#34;--Denver Post&#34;The complete and authentic adventures of the legendary detective--expertly edited and annotated by a team of Holmes scholars....in a handsome, boxed set....A lovely gift&#34;--The Christian Science Monitor&#34;Here in nine volumes...are all the adventures of Holmes and Watson. Each book has an introduction, something new and fascinating for even the most devoted Holmesians plus a series of intelligent notes at the back of each volume.&#34;--Oxford Times&#34;TheOxford Sherlock Holmes, a new edition of the stories, is a splendid piece of publishing. Nine compact volumes, beautifully produced, each with a stimulating introduction; clear type, accurate texts, a handy chronology, a helpful bibliography. And, most valuable of all, explanatory notes running to 50 pages or more per volume.&#34; --John Gross, writing inSunday Telegraph--This text refers to thePaperbackedition.",
#   'title': 'The Sherlock Holmes Audio Collection',
#   'price': 9.26,
#   'salesRank': {'Books': 8973864},
#   'imUrl': 'http://ecx.images-amazon.com/images/I/51DH145C5JL.jpg',
#   'related': {'also_viewed': ['1442300191',
#     '9626349786',
#     '1602837155',
#     '1598879162',
#     '1400115159',
#     '1478396202',
#     '1408426250',
#     'B007PM2A4A',
#     '1609980603'],
#    'buy_after_viewing': ['0312089457']}},
#  {'asin': '0000401048',
#   'title': "The rogue of publishers' row;: Confessions of a publisher (A Banner Book)",
#   'imUrl': 'http://ecx.images-amazon.com/images/I/41bchvIfgaL.jpg',
#   'related': {'also_viewed': ['068240103X']},
#   'salesRank': {'Books': 6448843},
#   'categories': [['Books']]},
#  {'asin': '0001019880',
#   'title': "Classic Soul Winner's New Testament Bible",
#   'price': 5.39,
#   'imUrl': 'http://ecx.images-amazon.com/images/I/61LcHUdvS1L.jpg',
#   'related': {'also_viewed': ['B003HMB5FC', '0834004593'],
#    'buy_after_viewing': ['031095360X', '0834004577']},
#   'salesRank': {'Books': 9589258},
#   'categories': [['Books']]},
#  {'asin': '0001048813',
#   'imUrl': 'http://ecx.images-amazon.com/images/I/41k5u0lr6NL.jpg',
#   'categories': [['Books']],
#   'title': 'Archer Christmas 4 Tape Pack'},
#  {'asin': '0001148427',
#   'salesRank': {'Books': 5806769},
#   'imUrl': 'http://ecx.images-amazon.com/images/I/41tN4KuOXkL.jpg',
#   'categories': [['Books']],
#   'title': 'Sonatas - For Piano'},
#  {'asin': '0001057170',
#   'description': "[Editor's Note: The following is a combined review with CLASSIC CONNOLLY IN WORDS AND MUSIC.]--Those of you who enjoyed Billy Connolly's moving performance in the film MRS. BROWN may not know (or believe) that he began his professional life as a Glasgow folky and gained first fame as a stand-up comic. Now's your chance to catch up on his sordid past with these compilations from his club recordings of the '70s and '80s. He loves the shaggy dog story and the wicked song but doesn't mind flinging one-liners either. His raucous, scatological, profane humor is best enjoyed by heavy drinkers familiar with the Scottish tongue. The rest of us will get plenty of yuks from those punch lines we can decipher.  Y.R. &copy; AudioFile 2001, Portland, Maine--Copyright &#169; AudioFile, Portland, Maine",
#   'title': 'Classic Connolly Boxed Set (Vol 1 &amp; 2)',
#   'imUrl': 'http://ecx.images-amazon.com/images/I/51M65KR89XL.jpg',
#   'salesRank': {'Books': 9318563},
#   'categories': [['Books']]},
#  {'asin': '0001047566',
#   'salesRank': {'Books': 3628249},
#   'imUrl': 'http://ecx.images-amazon.com/images/I/51FWARNTHCL.jpg',
#   'categories': [['Books']],
#   'title': 'Hand in Glove'},
#  {'asin': '0001053396',
#   'description': 'Writing poetry has always been a way to express what is going on in the world around us. Unfortunately, sometimes what is around us is war. Acclaimed British actor Paul McGann reads poems that date from the eighteenth century to modern times in this moving audio anthology. McGann is originally from Liverpool, and he still retains a slight Northern accent. Its lilting cadence blends well with the rhythm and worldliness of these powerful poems. Although some of the pieces are well known, others are less so, and this makes the collection even more intriguing for lovers of literature.  R.A.P. &copy; AudioFile 2001, Portland, Maine--Copyright &#169; AudioFile, Portland, Maine',
#   'title': 'War Poems: An Anthology of Poetry from the 18th Cantury to the Present Day',
#   'price': 17.99,
#   'imUrl': 'http://ecx.images-amazon.com/images/I/51WTKK4V2DL.jpg',
#   'salesRank': {'Books': 12249714},
#   'categories': [['Books']]},
#  {'asin': '0000913154',
#   'title': 'The Way Things Work: An Illustrated Encyclopedia of Technology',
#   'price': 23.26,
#   'imUrl': 'http://ecx.images-amazon.com/images/I/7113akhDnTL.jpg',
#   'related': {'also_bought': ['0590429892',
#     '1114119512',
#     'B000HW2YQE',
#     '0395938473',
#     '0395428572',
#     '0449208133',
#     '0486217094',
#     '0618233784',
#     '0486443604',
#     '1856698769',
#     '0942364155',
#     '0936070129',
#     '0671224549'],
#    'buy_after_viewing': ['0395938473',
#     'B000GP0CT8',
#     '0590429892',
#     '1114119512']},
#   'salesRank': {'Books': 455782},
#   'categories': [['Books']]},
#  {'asin': '0001072986',
#   'description': 'William Shakespeare is widely regarded as the greatest playwright the world has seen. He produced an astonishing amount of work; 37 plays, 154 sonnets, and 5 poems. He died on 23rd April 1616, aged 52, and was buried in the Holy Trinity Church, Stratford.',
#   'title': 'As You Like it: Complete &amp; Unabridged',
#   'imUrl': 'http://ecx.images-amazon.com/images/I/51X8Z6CJ10L.jpg',
#   'salesRank': {'Books': 8296784},
#   'categories': [['Books']]},
#  {'asin': '0001053744',
#   'categories': [['Books']],
#   'description': "While many readers are familiar with SIR GAWAIN AND THE GREEN KNIGHT (and perhaps even Tolkien's translation), these poems from the same fourteenth-century manuscript are less well known. PEARL the longer of the two, is an elegy for the poet's baby daughter, told in alliterative verse. SIR ORFEO is a Celtic version of the Greek myth of Orpheus and Eurydice, complete with a happy ending that the older story lacks. Terry Jones, former member of Monty Python and a medieval scholar to boot, sounds perfectly comfortable with the rhythms and language. One even gets a taste of the original Middle English on the final side, when Jones puts these works into context by reading Tolkien's own introductions.  D.B. &copy; AudioFile 2001, Portland, Maine--Copyright &#169; AudioFile, Portland, Maine",
#   'title': 'Pearl and Sir Orfeo',
#   'price': 6.05,
#   'salesRank': {'Books': 5665835},
#   'imUrl': 'http://ecx.images-amazon.com/images/I/712C-G3XiTL.jpg',
#   'related': {'also_viewed': ['0345277600'],
#    'buy_after_viewing': ['0312248733', '0345277600', '0140442898']}},
#  {'asin': '0001055178',
#   'categories': [['Books']],
#   'description': 'Beryl Bainbridge seems drawn to disaster. First she tackled the  unfortunate Scott expedition to the South Pole inThe Birthday Boys; later (but emphatically pre-DiCaprio) came the sinking of the Titanic, inEvery Man for Himself. Now, in her 3rd historical novel (and her 16th overall), she takes on the Crimean War, and the result is a slim, gripping volume with all of the doomed intensity of the Light Brigade\'s charge--but, thankfully, without the Tennysonian bombast. "Some pictures," a character confides, "would only cause alarm to ordinary folk." There\'s a warning concealed here, and one that easily disturbed readers would do well to heed:Master Georgieis intense, disturbing, revelatory--and not always pretty to look at.Bainbridge\'s narrative circles round the enigmatic figure of George Hardy, a surgeon, amateur photographer, alcoholic, and repressed homosexual who counters the dissipation of his prosperous Liverpool life by heading for the Crimean Peninsula in 1854. His journey and subsequent tour of duty are told in three very different voices: Myrtle, an orphan whose lifelong loyalty to her "Master Georgie" becomes an overriding obsession; Pompey Jones, street urchin, fire-eater, photographer, and George\'s sometime lover; and Dr. Potter, George\'s scholarly brother-in-law, whose retreat from the war\'s carnage and into books takes on a tinge of madness.United by a sudden death in a Liverpool brothel in 1846, these characters plumb the curious workings of love, war, class, and fate. In between, Bainbridge frames an unforgettable series oftableaux morts: a dying soldier, one lens of his glasses "fractured into a spider\'s web"; a decapitated leg, toes "poking through the shreds of a cavalry boot"; two dead men "on their knees, facing one another, propped up by the pat-a-cake thrust of their hands." Glimpsed as if sidewise and then passed over in language that is as understated as it is lovely, these are images that sear into the brain.Master Georgieis full of such moments, horrors painted with an exquisite brush.--Mary Park--This text refers to an out of print or unavailable edition of this title.',
#   'title': 'Master Georgie',
#   'price': 16.95,
#   'salesRank': {'Books': 14149327},
#   'imUrl': 'http://ecx.images-amazon.com/images/I/51ZSC6TKS3L.jpg',
#   'related': {'also_viewed': ['0349116156',
#     '0307947726',
#     '0786702079',
#     '0786701463',
#     '0786707739',
#     'B001IDZK0I',
#     '0226743497',
#     '0786703229',
#     '0802142818',
#     '0375700234',
#     '0679731369',
#     '0812976533',
#     '0385722109',
#     '1609450868',
#     '1416562605',
#     'B000GH2YRY',
#     '0679777504',
#     '1590170180',
#     'B001LF2H7W',
#     '0374526400',
#     '0807608815',
#     '1573225436',
#     '1609450566',
#     'B003H4RCJS',
#     '1586420046',
#     '0143124870',
#     '0571319661',
#     '0385474547',
#     '0140092552',
#     '0316074314'],
#    'buy_after_viewing': ['0349116156',
#     '1609450868',
#     '0307947726',
#     'B008SM8T5K']}},
#  {'asin': '0001064487',
#   'title': 'Celebremos Su Gloria',
#   'imUrl': 'http://ecx.images-amazon.com/images/I/41bI6DhG7SL.jpg',
#   'related': {'also_viewed': ['9589269117',
#     '9589269125',
#     '9589269109',
#     '9589269273',
#     '9588201748'],
#    'buy_after_viewing': ['9589269117', '9589269125', '9589269109']},
#   'salesRank': {'Books': 1549956},
#   'categories': [['Books']]}]

# %%
# Converting list of dictionaries to dataframe
meta_books_df = pd.DataFrame(records)

# %%
meta_books_df.T
# Out:
#                                                             0   \
# asin                                                0001048791
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/51MKP0T4...
# price                                                      NaN
# related                                                    NaN
# salesRank                                   {'Books': 6334800}
# title        The Crucible: Performed by Stuart Pankin, Jero...
#
#                                                             1   \
# asin                                                0001048775
# categories                                           [[Books]]
# description  William Shakespeare is widely regarded as the ...
# imUrl        http://ecx.images-amazon.com/images/I/5166EBHD...
# price                                                      NaN
# related                                                    NaN
# salesRank                                  {'Books': 13243226}
# title           Measure for Measure: Complete &amp; Unabridged
#
#                                                             2   \
# asin                                                0001048236
# categories                                           [[Books]]
# description  &#34;One thing is certain, Sherlockians, put a...
# imUrl        http://ecx.images-amazon.com/images/I/51DH145C...
# price                                                     9.26
# related      {'also_viewed': ['1442300191', '9626349786', '...
# salesRank                                   {'Books': 8973864}
# title                     The Sherlock Holmes Audio Collection
#
#                                                             3   \
# asin                                                0000401048
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/41bchvIf...
# price                                                      NaN
# related                        {'also_viewed': ['068240103X']}
# salesRank                                   {'Books': 6448843}
# title        The rogue of publishers' row;: Confessions of ...
#
#                                                             4   \
# asin                                                0001019880
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/61LcHUdv...
# price                                                     5.39
# related      {'also_viewed': ['B003HMB5FC', '0834004593'], ...
# salesRank                                   {'Books': 9589258}
# title                Classic Soul Winner's New Testament Bible
#
#                                                             5   \
# asin                                                0001048813
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/41k5u0lr...
# price                                                      NaN
# related                                                    NaN
# salesRank                                                  NaN
# title                             Archer Christmas 4 Tape Pack
#
#                                                             6   \
# asin                                                0001148427
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/41tN4KuO...
# price                                                      NaN
# related                                                    NaN
# salesRank                                   {'Books': 5806769}
# title                                      Sonatas - For Piano
#
#                                                             7   \
# asin                                                0001057170
# categories                                           [[Books]]
# description  [Editor's Note: The following is a combined re...
# imUrl        http://ecx.images-amazon.com/images/I/51M65KR8...
# price                                                      NaN
# related                                                    NaN
# salesRank                                   {'Books': 9318563}
# title               Classic Connolly Boxed Set (Vol 1 &amp; 2)
#
#                                                             8   \
# asin                                                0001047566
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/51FWARNT...
# price                                                      NaN
# related                                                    NaN
# salesRank                                   {'Books': 3628249}
# title                                            Hand in Glove
#
#                                                             9   \
# asin                                                0001053396
# categories                                           [[Books]]
# description  Writing poetry has always been a way to expres...
# imUrl        http://ecx.images-amazon.com/images/I/51WTKK4V...
# price                                                    17.99
# related                                                    NaN
# salesRank                                  {'Books': 12249714}
# title        War Poems: An Anthology of Poetry from the 18t...
#
#                                                             10  \
# asin                                                0000913154
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/7113akhD...
# price                                                    23.26
# related      {'also_bought': ['0590429892', '1114119512', '...
# salesRank                                    {'Books': 455782}
# title        The Way Things Work: An Illustrated Encycloped...
#
#                                                             11  \
# asin                                                0001072986
# categories                                           [[Books]]
# description  William Shakespeare is widely regarded as the ...
# imUrl        http://ecx.images-amazon.com/images/I/51X8Z6CJ...
# price                                                      NaN
# related                                                    NaN
# salesRank                                   {'Books': 8296784}
# title                As You Like it: Complete &amp; Unabridged
#
#                                                             12  \
# asin                                                0001053744
# categories                                           [[Books]]
# description  While many readers are familiar with SIR GAWAI...
# imUrl        http://ecx.images-amazon.com/images/I/712C-G3X...
# price                                                     6.05
# related      {'also_viewed': ['0345277600'], 'buy_after_vie...
# salesRank                                   {'Books': 5665835}
# title                                      Pearl and Sir Orfeo
#
#                                                             13  \
# asin                                                0001055178
# categories                                           [[Books]]
# description  Beryl Bainbridge seems drawn to disaster. Firs...
# imUrl        http://ecx.images-amazon.com/images/I/51ZSC6TK...
# price                                                    16.95
# related      {'also_viewed': ['0349116156', '0307947726', '...
# salesRank                                  {'Books': 14149327}
# title                                           Master Georgie
#
#                                                             14
# asin                                                0001064487
# categories                                           [[Books]]
# description                                                NaN
# imUrl        http://ecx.images-amazon.com/images/I/41bI6DhG...
# price                                                      NaN
# related      {'also_viewed': ['9589269117', '9589269125', '...
# salesRank                                   {'Books': 1549956}
# title                                     Celebremos Su Gloria

# %%
#Writing dataframes to csv and dump in S3 

from io import StringIO

csv_buffer = StringIO()
meta_books_df.to_csv(csv_buffer)
s3_resource = boto3.resource('s3')
s3_resource.Object('santhoshi-sparkle', 'amazon-data/meta_books_df.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': '72B4046A9CCCB9CE',
#   'HostId': 'eqgWPHF/NIvlSMF8ttJ5geqrVANcPUXXbJZmnxmLdcW6WxmS9aqGKK2nX+5c8mrth2ngFFd0yig=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'eqgWPHF/NIvlSMF8ttJ5geqrVANcPUXXbJZmnxmLdcW6WxmS9aqGKK2nX+5c8mrth2ngFFd0yig=',
#    'x-amz-request-id': '72B4046A9CCCB9CE',
#    'date': 'Thu, 02 Aug 2018 01:18:11 GMT',
#    'etag': '"a7f476ad7ccb0ebd5f227339c6a48762"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"a7f476ad7ccb0ebd5f227339c6a48762"'}

# %%
test_df = pd.read_csv(smart_open('s3://santhoshi-sparkle/amazon-data/meta_books_df.csv'))

# %%
test_df
# Out:
#     Unnamed: 0     asin   categories  \
# 0            0  1048791  [['Books']]
# 1            1  1048775  [['Books']]
# 2            2  1048236  [['Books']]
# 3            3   401048  [['Books']]
# 4            4  1019880  [['Books']]
# 5            5  1048813  [['Books']]
# 6            6  1148427  [['Books']]
# 7            7  1057170  [['Books']]
# 8            8  1047566  [['Books']]
# 9            9  1053396  [['Books']]
# 10          10   913154  [['Books']]
# 11          11  1072986  [['Books']]
# 12          12  1053744  [['Books']]
# 13          13  1055178  [['Books']]
# 14          14  1064487  [['Books']]
#
#                                           description  \
# 0                                                 NaN
# 1   William Shakespeare is widely regarded as the ...
# 2   &#34;One thing is certain, Sherlockians, put a...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   [Editor's Note: The following is a combined re...
# 8                                                 NaN
# 9   Writing poetry has always been a way to expres...
# 10                                                NaN
# 11  William Shakespeare is widely regarded as the ...
# 12  While many readers are familiar with SIR GAWAI...
# 13  Beryl Bainbridge seems drawn to disaster. Firs...
# 14                                                NaN
#
#                                                 imUrl  price  \
# 0   http://ecx.images-amazon.com/images/I/51MKP0T4...    NaN
# 1   http://ecx.images-amazon.com/images/I/5166EBHD...    NaN
# 2   http://ecx.images-amazon.com/images/I/51DH145C...   9.26
# 3   http://ecx.images-amazon.com/images/I/41bchvIf...    NaN
# 4   http://ecx.images-amazon.com/images/I/61LcHUdv...   5.39
# 5   http://ecx.images-amazon.com/images/I/41k5u0lr...    NaN
# 6   http://ecx.images-amazon.com/images/I/41tN4KuO...    NaN
# 7   http://ecx.images-amazon.com/images/I/51M65KR8...    NaN
# 8   http://ecx.images-amazon.com/images/I/51FWARNT...    NaN
# 9   http://ecx.images-amazon.com/images/I/51WTKK4V...  17.99
# 10  http://ecx.images-amazon.com/images/I/7113akhD...  23.26
# 11  http://ecx.images-amazon.com/images/I/51X8Z6CJ...    NaN
# 12  http://ecx.images-amazon.com/images/I/712C-G3X...   6.05
# 13  http://ecx.images-amazon.com/images/I/51ZSC6TK...  16.95
# 14  http://ecx.images-amazon.com/images/I/41bI6DhG...    NaN
#
#                                               related            salesRank  \
# 0                                                 NaN   {'Books': 6334800}
# 1                                                 NaN  {'Books': 13243226}
# 2   {'also_viewed': ['1442300191', '9626349786', '...   {'Books': 8973864}
# 3                     {'also_viewed': ['068240103X']}   {'Books': 6448843}
# 4   {'also_viewed': ['B003HMB5FC', '0834004593'], ...   {'Books': 9589258}
# 5                                                 NaN                  NaN
# 6                                                 NaN   {'Books': 5806769}
# 7                                                 NaN   {'Books': 9318563}
# 8                                                 NaN   {'Books': 3628249}
# 9                                                 NaN  {'Books': 12249714}
# 10  {'also_bought': ['0590429892', '1114119512', '...    {'Books': 455782}
# 11                                                NaN   {'Books': 8296784}
# 12  {'also_viewed': ['0345277600'], 'buy_after_vie...   {'Books': 5665835}
# 13  {'also_viewed': ['0349116156', '0307947726', '...  {'Books': 14149327}
# 14  {'also_viewed': ['9589269117', '9589269125', '...   {'Books': 1549956}
#
#                                                 title
# 0   The Crucible: Performed by Stuart Pankin, Jero...
# 1      Measure for Measure: Complete &amp; Unabridged
# 2                The Sherlock Holmes Audio Collection
# 3   The rogue of publishers' row;: Confessions of ...
# 4           Classic Soul Winner's New Testament Bible
# 5                        Archer Christmas 4 Tape Pack
# 6                                 Sonatas - For Piano
# 7          Classic Connolly Boxed Set (Vol 1 &amp; 2)
# 8                                       Hand in Glove
# 9   War Poems: An Anthology of Poetry from the 18t...
# 10  The Way Things Work: An Illustrated Encycloped...
# 11          As You Like it: Complete &amp; Unabridged
# 12                                Pearl and Sir Orfeo
# 13                                     Master Georgie
# 14                               Celebremos Su Gloria
